# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
df_users = pd.read_csv(url, sep='|')
df_users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
df_users.groupby("occupation").count()
# Out:
#                user_id  age  gender  zip_code
# occupation
# administrator       79   79      79        79
# artist              28   28      28        28
# doctor               7    7       7         7
# educator            95   95      95        95
# engineer            67   67      67        67
# entertainment       18   18      18        18
# executive           32   32      32        32
# healthcare          16   16      16        16
# homemaker            7    7       7         7
# lawyer              12   12      12        12
# librarian           51   51      51        51
# marketing           26   26      26        26
# none                 9    9       9         9
# other              105  105     105       105
# programmer          66   66      66        66
# retired             14   14      14        14
# salesman            12   12      12        12
# scientist           31   31      31        31
# student            196  196     196       196
# ...

# %%
df_users[df_users.occupation.isin(["administrator","student"])].groupby("age").count()
# Out:
#      user_id  gender  occupation  zip_code
# age
# 7          1       1           1         1
# 10         1       1           1         1
# 13         3       3           3         3
# 14         3       3           3         3
# 15         5       5           5         5
# 16         4       4           4         4
# 17        13      13          13        13
# 18        13      13          13        13
# 19        21      21          21        21
# 20        25      25          25        25
# 21        14      14          14        14
# 22        24      24          24        24
# 23        13      13          13        13
# 24         8       8           8         8
# 25        14      14          14        14
# 26         9       9           9         9
# 27         9       9           9         9
# 28        12      12          12        12
# 29         7       7           7         7
# 30         8       8           8         8
# 31         4       4           4         4
# ...

# %%
df_users[df_users['gender'] == "M"].groupby("age").count()
# Out:
#      user_id  gender  occupation  zip_code
# age
# 7          1       1           1         1
# 10         1       1           1         1
# 11         1       1           1         1
# 13         3       3           3         3
# 15         3       3           3         3
# 16         3       3           3         3
# 17        11      11          11        11
# 18         7       7           7         7
# 19        15      15          15        15
# 20        22      22          22        22
# 21        20      20          20        20
# 22        30      30          30        30
# 23        22      22          22        22
# 24        27      27          27        27
# 25        30      30          30        30
# 26        25      25          25        25
# 27        25      25          25        25
# 28        26      26          26        26
# 29        20      20          20        20
# 30        27      27          27        27
# 31        19      19          19        19
# ...

# %%
df_users.query("occupation == 'student'").groupby(['occupation','gender']).count()
# Out:
#                    user_id  age  zip_code
# occupation gender
# student    F            60   60        60
#            M           136  136       136

# %%
df_users[df_users['occupation'] == "student"].groupby(["occupation","gender"]).count()
# Out:
#                    user_id  age  zip_code
# occupation gender
# student    F            60   60        60
#            M           136  136       136

# %%
df_users.query("occupation == 'student'").groupby(['gender']).count()
# Out:
#         user_id  age  occupation  zip_code
# gender
# F            60   60          60        60
# M           136  136         136       136

# %%
df_users[df_users['occupation'] == "student"].groupby(["gender"]).count()
# Out:
#         user_id  age  occupation  zip_code
# gender
# F            60   60          60        60
# M           136  136         136       136

# %%
df_users.groupby("age").count()
# Out:
#      user_id  gender  occupation  zip_code
# age
# 7          1       1           1         1
# 10         1       1           1         1
# 11         1       1           1         1
# 13         5       5           5         5
# 14         3       3           3         3
# ..       ...     ...         ...       ...
# 66         1       1           1         1
# 68         2       2           2         2
# 69         2       2           2         2
# 70         3       3           3         3
# 73         1       1           1         1
#
# [61 rows x 4 columns]

# %%
df_users.query("occupation == ['student','administrator']").groupby("gender").count()
# Out:
#         user_id  age  occupation  zip_code
# gender
# F            96   96          96        96
# M           179  179         179       179

# %%
df_users.query("occupation == ['student','administrator']")
# Out:
#      user_id  age gender     occupation zip_code
# 6          7   57      M  administrator    91344
# 7          8   36      M  administrator    05201
# 8          9   29      M        student    01002
# 29        30    7      M        student    55436
# 31        32   28      F        student    78741
# ..       ...  ...    ...            ...      ...
# 932      933   28      M        student    48105
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 942      943   22      M        student    77841
#
# [275 rows x 5 columns]

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'],
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}

# %%
regiment = pd.DataFrame(raw_data, columns = raw_data.keys())
regiment
# Out:
#       regiment company      name  preTestScore  postTestScore
# 0   Nighthawks     1st    Miller             4             25
# 1   Nighthawks     1st  Jacobson            24             94
# 2   Nighthawks     2nd       Ali            31             57
# 3   Nighthawks     2nd    Milner             2             62
# 4     Dragoons     1st     Cooze             3             70
# 5     Dragoons     1st     Jacon             4             25
# 6     Dragoons     2nd    Ryaner            24             94
# 7     Dragoons     2nd      Sone            31             57
# 8       Scouts     1st     Sloan             2             62
# 9       Scouts     1st     Piger             3             70
# 10      Scouts     2nd     Riani             2             62
# 11      Scouts     2nd       Ali             3             70

# %%
regiment.query("regiment == 'Scouts'").groupby("regiment").count()
# Out:
#           company  name  preTestScore  postTestScore
# regiment
# Scouts          4     4             4              4

# %%
regiment.query("regiment == ['Scouts','Dragoons']").groupby("regiment").count()
# Out:
#           company  name  preTestScore  postTestScore
# regiment
# Dragoons        4     4             4              4
# Scouts          4     4             4              4

# %%
regiment.query("regiment == 'Scouts' and company == '2nd'").groupby("regiment").count()
# Out:
#           company  name  preTestScore  postTestScore
# regiment
# Scouts          2     2             2              2

# %%
regiment.groupby(["company", "regiment"]).size()
# Out:
# company  regiment
# 1st      Dragoons      2
#          Nighthawks    2
#          Scouts        2
# 2nd      Dragoons      2
#          Nighthawks    2
#          Scouts        2
# dtype: int64

# %%
regiment[regiment["preTestScore"] == 3].groupby(["company","regiment"]).size()
# Out:
# company  regiment
# 1st      Dragoons    1
#          Scouts      1
# 2nd      Scouts      1
# dtype: int64

# %%
regiment.dtypes
# Out:
# regiment         object
# company          object
# name             object
# preTestScore      int64
# postTestScore     int64
# dtype: object

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'

# %%
crime = pd.read_csv(url, sep = ",")
crime
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
crime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
crime.tail()
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 50  2010   309330219  10363873  1251248   9112625   14772          85593
# 51  2011   311587816  10258774  1206031   9052743   14661          84175
# 52  2012   313873685  10219059  1217067   9001992   14866          85141
# 53  2013   316497531   9850445  1199684   8650761   14319          82109
# 54  2014   318857056   9475816  1197987   8277829   14249          84041
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 50   369089              781844   2168457        6204601         739565
# 51   354772              752423   2185140        6151095         716508
# 52   355051              762009   2109932        6168874         723186
# 53   345095              726575   1931835        6018632         700294
# 54   325802              741291   1729806        5858496         689527

# %%
crime.max()
# Out:
# Year                       2014
# Population            318857056
# Total                  14872900
# Violent                 1932270
# Property               12961100
# Murder                    24700
# Forcible_Rape            109060
# Robbery                  687730
# Aggravated_assault      1135610
# Burglary                3795200
# Larceny_Theft           8142200
# Vehicle_Theft           1661700
# dtype: int64

# %%
crime.min()
# Out:
# Year                       1960
# Population            179323175
# Total                   3384200
# Violent                  288460
# Property                3095700
# Murder                     8530
# Forcible_Rape             17190
# Robbery                  106670
# Aggravated_assault       154320
# Burglary                 912100
# Larceny_Theft           1855400
# Vehicle_Theft            328200
# dtype: int64

# %%
crime.max(axis = "index")
# Out:
# Year                       2014
# Population            318857056
# Total                  14872900
# Violent                 1932270
# Property               12961100
# Murder                    24700
# Forcible_Rape            109060
# Robbery                  687730
# Aggravated_assault      1135610
# Burglary                3795200
# Larceny_Theft           8142200
# Vehicle_Theft           1661700
# dtype: int64

# %%
crime.Murder.unique()
# Out:
# array([ 9110,  8740,  8530,  8640,  9360,  9960, 11040, 12240, 13800,
#        14760, 16000, 17780, 18670, 19640, 20710, 20510, 18780, 19120,
#        19560, 21460, 23040, 22520, 21010, 19310, 18690, 18980, 20613,
#        20096, 20680, 21500, 23440, 24700, 23760, 24530, 23330, 21610,
#        19650, 18208, 16914, 15522, 15586, 16037, 16229, 16528, 16148,
#        16740, 17030, 16929, 16442, 15399, 14772, 14661, 14866, 14319,
#        14249])

# %%
crime[["Year", "Murder"]]
# Out:
#     Year  Murder
# 0   1960    9110
# 1   1961    8740
# 2   1962    8530
# 3   1963    8640
# 4   1964    9360
# 5   1965    9960
# 6   1966   11040
# 7   1967   12240
# 8   1968   13800
# 9   1969   14760
# 10  1970   16000
# 11  1971   17780
# 12  1972   18670
# 13  1973   19640
# 14  1974   20710
# 15  1975   20510
# 16  1976   18780
# 17  1977   19120
# 18  1978   19560
# 19  1979   21460
# 20  1980   23040
# 21  1981   22520
# 22  1982   21010
# 23  1983   19310
# 24  1984   18690
# 25  1985   18980
# 26  1986   20613
# 27  1987   20096
# 28  1988   20680
# 29  1989   21500
# 30  1990   23440
# 31  1991   24700
# 32  1992   23760
# 33  1993   24530
# 34  1994   23330
# 35  1995   21610
# 36  1996   19650
# 37  1997   18208
# 38  1998   16914
# 39  1999   15522
# 40  2000   15586
# 41  2001   16037
# 42  2002   16229
# 43  2003   16528
# 44  2004   16148
# 45  2005   16740
# 46  2006   17030
# 47  2007   16929
# 48  2008   16442
# 49  2009   15399
# 50  2010   14772
# ...

# %%
crime.Murder.sum()
# Out:
# 952448

# %%
crime.describe()
# Out:
#              Year    Population         Total       Violent      Property  \
# count    55.00000  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   1987.00000  2.461556e+08  1.060315e+07  1.188806e+06  9.412499e+06
# std      16.02082  4.166216e+07  3.175931e+06  4.597107e+05  2.738512e+06
# min    1960.00000  1.793232e+08  3.384200e+06  2.884600e+05  3.095700e+06
# 25%    1973.50000  2.106215e+08  9.096958e+06  9.253150e+05  8.060014e+06
# 50%    1987.00000  2.422829e+08  1.140151e+07  1.322390e+06  1.018259e+07
# 75%    2000.50000  2.833697e+08  1.308449e+07  1.432762e+06  1.160509e+07
# max    2014.00000  3.188571e+08  1.487290e+07  1.932270e+06  1.296110e+07
#
#              Murder  Forcible_Rape        Robbery  Aggravated_assault  \
# count     55.000000      55.000000      55.000000        5.500000e+01
# mean   17317.236364   72714.800000  416449.890909        6.811818e+05
# std     4267.442664   28278.006893  150506.403782        2.960255e+05
# ...

# %%
crime.Robbery.sum()
# Out:
# 22904744

# %%
crime.iloc[20:40,:]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 20  1980   225349264  13408300  1344520  12063700   23040          82990
# 21  1981   229146000  13423800  1361820  12061900   22520          82500
# 22  1982   231534000  12974400  1322390  11652000   21010          78770
# 23  1983   233981000  12108600  1258090  10850500   19310          78920
# 24  1984   236158000  11881800  1273280  10608500   18690          84230
# 25  1985   238740000  12431400  1328800  11102600   18980          88670
# 26  1986   240132887  13211869  1489169  11722700   20613          91459
# 27  1987   242282918  13508700  1483999  12024700   20096          91110
# 28  1988   245807000  13923100  1566220  12356900   20680          92490
# 29  1989   248239000  14251400  1646040  12605400   21500          94500
# 30  1990   248709873  14475600  1820130  12655500   23440         102560
# 31  1991   252177000  14872900  1911770  12961100   24700         106590
# ...

# %%
crime.dtypes
# Out:
# Year                  int64
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %%
tmpcrime = crime
tmpcrime = tmpcrime.rename(index = tmpcrime.Year)
tmpcrime.loc[1990:,"Year":"Total"]
# Out:
#       Year  Population     Total
# 1990  1990   248709873  14475600
# 1991  1991   252177000  14872900
# 1992  1992   255082000  14438200
# 1993  1993   257908000  14144800
# 1994  1994   260341000  13989500
# 1995  1995   262755000  13862700
# 1996  1996   265228572  13493863
# 1997  1997   267637000  13194571
# 1998  1998   270296000  12475634
# 1999  1999   272690813  11634378
# 2000  2000   281421906  11608072
# 2001  2001   285317559  11876669
# 2002  2002   287973924  11878954
# 2003  2003   290690788  11826538
# 2004  2004   293656842  11679474
# 2005  2005   296507061  11565499
# 2006  2006   299398484  11401511
# 2007  2007   301621157  11251828
# 2008  2008   304374846  11160543
# 2009  2009   307006550  10762956
# 2010  2010   309330219  10363873
# 2011  2011   311587816  10258774
# 2012  2012   313873685  10219059
# 2013  2013   316497531   9850445
# 2014  2014   318857056   9475816

# %%
crime[crime.Year == 1996]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 36  1996   265228572  13493863  1688540  11805300   19650          96250
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 36   535590             1037050   2506400        7904700        1394200

# %%
uscrime = crime
uscrime.drop(columns = ["Population","Total"]).query("Year == [1992,1994,1996,1998]")
# Out:
#     Year  Violent  Property  Murder  Forcible_Rape  Robbery  \
# 32  1992  1932270  12505900   23760         109060   672480
# 34  1994  1857670  12131900   23330         102220   618950
# 36  1996  1688540  11805300   19650          96250   535590
# 38  1998  1531044  10944590   16914          93103   446625
#
#     Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 32             1126970   2979900        7915200        1610800
# 34             1113180   2712800        7879800        1539300
# 36             1037050   2506400        7904700        1394200
# 38              974402   2329950        7373886        1240754

# %%
crime.query("Year == [1992,1994,1996,1998] and Murder > 20000")[["Year","Population","Murder"]]
# Out:
#     Year  Population  Murder
# 32  1992   255082000   23760
# 34  1994   260341000   23330

# %%
crime.loc[:,"Violent":].query()

# %%
crime
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %%
data1 = pd.DataFrame(raw_data_1, columns = ['subject_id', 'first_name', 'last_name'])
data2 = pd.DataFrame(raw_data_2, columns = ['subject_id', 'first_name', 'last_name'])
data3 = pd.DataFrame(raw_data_3, columns = ['subject_id','test_id'])

# %%
data1
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %%
data2
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
data_new = pd.concat([data1, data2])
data_new
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
data_new_row = pd.concat([data1, data2], axis=0)
data_new_row
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
data_new_col = pd.concat([data1, data2], axis=1)
data_new_col
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %%
pd.merge(data_new, data3, on='subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15
