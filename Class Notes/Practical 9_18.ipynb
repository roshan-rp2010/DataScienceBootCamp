# %%
import pandas as pd
import numpy as np

path = "/content/demo_data.xlsx - Sheet1.csv"
df = pd.read_csv(path)
print(df)
# Out:
#     Worker   Wage  Education   Age
# 0      1.0  17.54         12  76.0
# 1      2.0  20.93         10  61.0
# 2      3.0  12.94          8  75.0
# 3      4.0  19.34          6  38.0
# 4      5.0  24.12         12  59.0
# ..     ...    ...        ...   ...
# 75    76.0  25.64         14  74.0
# 76    77.0  38.77         21  41.0
# 77    78.0  21.87         15  75.0
# 78    79.0  27.54         20  46.0
# 79    80.0  23.66         12  49.0
#
# [80 rows x 4 columns]

# %%
df.shape
# Out:
# (80, 4)

# %%
df.describe()
# Out:
#           Worker       Wage  Education        Age
# count  79.000000  79.000000  80.000000  79.000000
# mean   40.797468  25.102911  13.850000  49.544304
# std    23.232592   7.320181   4.016107  17.315916
# min     1.000000  10.030000   6.000000  18.000000
# 25%    21.500000  19.245000  10.000000  34.500000
# 50%    41.000000  25.070000  14.000000  51.000000
# 75%    60.500000  30.665000  17.000000  65.500000
# max    80.000000  43.440000  22.000000  77.000000

# %%
df.median()
# Out:
# Worker       41.00
# Wage         25.07
# Education    14.00
# Age          51.00
# dtype: float64

# %%
df.max()
# Out:
# Worker       80.00
# Wage         43.44
# Education    22.00
# Age          77.00
# dtype: float64

# %%
df.min()
# Out:
# Worker        1.00
# Wage         10.03
# Education     6.00
# Age          18.00
# dtype: float64

# %%
df.sum()
# Out:
# Worker       3223.00
# Wage         1983.13
# Education    1108.00
# Age          3914.00
# dtype: float64

# %%
df_zero = df.replace([-np.nan,np.nan], 0)
df_zero.describe()
# Out:
#           Worker       Wage  Education        Age
# count  80.000000  80.000000  80.000000  80.000000
# mean   40.287500  24.789125  13.850000  48.925000
# std    23.531392   7.796391   4.016107  18.075632
# min     0.000000   0.000000   6.000000   0.000000
# 25%    20.750000  19.145000  10.000000  34.000000
# 50%    40.500000  24.980000  14.000000  51.000000
# 75%    60.250000  30.572500  17.000000  65.250000
# max    80.000000  43.440000  22.000000  77.000000

# %%
df_updated = df.dropna()

# %%
df_updated.shape
# Out:
# (77, 4)

# %%
df_updated
# Out:
#     Worker   Wage  Education   Age
# 0      1.0  17.54         12  76.0
# 1      2.0  20.93         10  61.0
# 2      3.0  12.94          8  75.0
# 3      4.0  19.34          6  38.0
# 4      5.0  24.12         12  59.0
# ..     ...    ...        ...   ...
# 75    76.0  25.64         14  74.0
# 76    77.0  38.77         21  41.0
# 77    78.0  21.87         15  75.0
# 78    79.0  27.54         20  46.0
# 79    80.0  23.66         12  49.0
#
# [77 rows x 4 columns]

# %%
df_updated.describe()
# Out:
#           Worker       Wage  Education        Age
# count  77.000000  77.000000  77.000000  77.000000
# mean   41.571429  25.136364  14.000000  49.038961
# std    23.012256   7.396915   4.006574  17.247762
# min     1.000000  10.030000   6.000000  18.000000
# 25%    23.000000  19.150000  12.000000  34.000000
# 50%    42.000000  25.070000  14.000000  51.000000
# 75%    61.000000  30.850000  17.000000  64.000000
# max    80.000000  43.440000  22.000000  77.000000

# %%
df_updated.median()
# Out:
# Worker       42.00
# Wage         25.07
# Education    14.00
# Age          51.00
# dtype: float64

# %%
df_updated.sum()
# Out:
# Worker       3201.0
# Wage         1935.5
# Education    1078.0
# Age          3776.0
# dtype: float64

# %%
df_updated.max()
# Out:
# Worker       80.00
# Wage         43.44
# Education    22.00
# Age          77.00
# dtype: float64

# %%
df_updated.min()
# Out:
# Worker        1.00
# Wage         10.03
# Education     6.00
# Age          18.00
# dtype: float64

# %%
df_updated.Wage[df_updated["Age"] > 50].mean()
# Out:
# 26.29948717948718

# %%
df_updated.Wage[df_updated["Age"] < 20].mean()
# Out:
# 18.759999999999998

# %%
df_updated[df_updated.Wage == df_updated['Wage'].max()].iloc[0][2]
# Out:
# 20.0

# %%
df_updated.Education[df_updated.Wage == df_updated['Wage'].max()].iloc[0]
# Out:
# 20

# %%
df_updated.loc[df_updated.Wage == df_updated["Wage"].max(),"Education"]
# Out:
# 31    20
# Name: Education, dtype: int64

# %%
print(df_updated.loc[df_updated.Wage == df_updated["Wage"].max(),"Education":"Age"])
print(df_updated.loc[df_updated.Wage == df_updated["Wage"].min(),"Education":"Age"])
# Out:
#     Education   Age
# 31         20  43.0
#     Education   Age
# 56          9  22.0

# %%
df_updated.Education[df_updated.Wage.max()]

# %%
df_updated.groupby(["Education"]).max().Wage
# Out:
# Education
# 6     19.34
# 8     20.96
# 9     19.13
# 10    22.33
# 12    29.15
# 13    24.89
# 14    31.92
# 15    32.81
# 16    35.60
# 17    32.37
# 18    40.61
# 20    43.44
# 21    38.77
# 22    34.95
# Name: Wage, dtype: float64

# %%
dictionary_of_mean_wage = {}

for k in df_updated.Education.value_counts().keys():
  dictionary_of_mean_wage[k] = df_updated.Wage[df["Education"] == k].mean()

print(dictionary_of_mean_wage)
# Out:
# {12: 22.64363636363636, 16: 29.03875, 8: 17.398571428571426, 15: 27.24857142857143, 18: 31.545714285714286, 10: 19.378333333333334, 17: 28.680000000000003, 14: 27.10833333333333, 20: 32.54, 13: 19.302500000000002, 9: 14.11, 21: 35.39666666666667, 6: 16.134999999999998, 22: 34.95}

# %%
k = list(dictionary_of_mean_wage.keys())
v = list(dictionary_of_mean_wage.values())

print(k[v.index(max(v))])
# Out:
# 21
