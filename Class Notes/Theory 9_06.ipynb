# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df_chipotle = pd.read_csv(url, sep='\t')
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df_chipotle[df_chipotle.item_name == 'Chips and Fresh Tomato Salsa']
# Out:
#       order_id  quantity                     item_name choice_description  \
# 0            1         1  Chips and Fresh Tomato Salsa                NaN
# 25          13         1  Chips and Fresh Tomato Salsa                NaN
# 55          25         1  Chips and Fresh Tomato Salsa                NaN
# 89          39         1  Chips and Fresh Tomato Salsa                NaN
# 183         82         1  Chips and Fresh Tomato Salsa                NaN
# ...        ...       ...                           ...                ...
# 4231      1689         1  Chips and Fresh Tomato Salsa                NaN
# 4318      1722         1  Chips and Fresh Tomato Salsa                NaN
# 4324      1725         1  Chips and Fresh Tomato Salsa                NaN
# 4425      1764         1  Chips and Fresh Tomato Salsa                NaN
# 4503      1790         1  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 0        $2.39
# 25       $2.39
# 55       $2.39
# ...

# %%
df_chipotle.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df_chipotle["item_price"]
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df_chipotle['item_price'] = [float(str(i).replace("$","")) for i in df_chipotle["item_price"]]
df_chipotle["item_price"]
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
df_chipotle.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
dir(df_chipotle)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
df_chipotle.filter(like = "item",axis = 1)

# %%
df_chipotle.filter(items = ["choice","item_price"], axis = 1)

# %%
df_chipotle[df_chipotle.choice_description.isin(["[Fresh Tomato Salsa]","[Apple]","[Rice]"])]
# Out:
#       order_id  quantity           item_name    choice_description  item_price
# 2            1         1    Nantucket Nectar               [Apple]        3.39
# 173         77         1    Nantucket Nectar               [Apple]        3.39
# 724        299         1     Chicken Burrito  [Fresh Tomato Salsa]        8.75
# 1014       416         1        Chicken Bowl  [Fresh Tomato Salsa]        8.75
# 1560       634         1  Chicken Soft Tacos  [Fresh Tomato Salsa]        8.75
# 1706       690         1    Nantucket Nectar               [Apple]        3.39
# 2214       892         1          Steak Bowl  [Fresh Tomato Salsa]        9.25
# 2260       910         1        Chicken Bowl  [Fresh Tomato Salsa]        8.75
# 2381       947         1    Nantucket Nectar               [Apple]        3.39
# 2818      1118         1    Nantucket Nectar               [Apple]        3.39
# 2853      1133         1    Nantucket Nectar               [Apple]        3.39
# ...

# %%
df_chipotle[df_chipotle.item_name.isin(["Chicken Bowl","Chicken Burrito"])]
# Out:
#       order_id  quantity        item_name  \
# 4            2         2     Chicken Bowl
# 5            3         1     Chicken Bowl
# 13           7         1     Chicken Bowl
# 16           8         1  Chicken Burrito
# 17           9         1  Chicken Burrito
# ...        ...       ...              ...
# 4590      1825         1     Chicken Bowl
# 4591      1825         1     Chicken Bowl
# 4595      1826         1     Chicken Bowl
# 4599      1827         1     Chicken Bowl
# 4604      1828         1     Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 16    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 17    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...        8.49
# ...

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
df_users = pd.read_csv(url, sep='|')
df_users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
df_users.groupby("occupation").sum()
# Out:
# <ipython-input-58-41fe73e4fb02>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_users.groupby("occupation").sum()
#                user_id   age
# occupation
# administrator    34045  3061
# artist           12653   879
# doctor            3736   305
# educator         44356  3991
# engineer         30574  2438
# entertainment     7164   526
# executive        13514  1239
# healthcare        8023   665
# homemaker         3101   228
# lawyer            4309   441
# librarian        24816  2040
# marketing        11383   978
# none              3318   239
# other            56987  3625
# programmer       28745  2186
# retired           7220   883
# salesman          5939   428
# scientist        14419  1102
# student          95051  4328
# technician       13436   895
# ...

# %%
df_users.groupby("occupation").age.count()
# Out:
# occupation
# administrator     79
# artist            28
# doctor             7
# educator          95
# engineer          67
# entertainment     18
# executive         32
# healthcare        16
# homemaker          7
# lawyer            12
# librarian         51
# marketing         26
# none               9
# other            105
# programmer        66
# retired           14
# salesman          12
# scientist         31
# student          196
# technician        27
# writer            45
# Name: age, dtype: int64

# %%
df_users.min()
# Out:
# user_id                   1
# age                       7
# gender                    F
# occupation    administrator
# zip_code              00000
# dtype: object

# %%
df_users.max()
# Out:
# user_id          943
# age               73
# gender             M
# occupation    writer
# zip_code       Y1A6B
# dtype: object

# %%
df_users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
df_users.groupby("occupation").count()
# Out:
#                user_id  age  gender  zip_code
# occupation
# administrator       79   79      79        79
# artist              28   28      28        28
# doctor               7    7       7         7
# educator            95   95      95        95
# engineer            67   67      67        67
# entertainment       18   18      18        18
# executive           32   32      32        32
# healthcare          16   16      16        16
# homemaker            7    7       7         7
# lawyer              12   12      12        12
# librarian           51   51      51        51
# marketing           26   26      26        26
# none                 9    9       9         9
# other              105  105     105       105
# programmer          66   66      66        66
# retired             14   14      14        14
# salesman            12   12      12        12
# scientist           31   31      31        31
# student            196  196     196       196
# ...

# %%
df_users[df_users.occupation.isin(["administrator","student"])].groupby("age").count()
# Out:
#      user_id  gender  occupation  zip_code
# age
# 7          1       1           1         1
# 10         1       1           1         1
# 13         3       3           3         3
# 14         3       3           3         3
# 15         5       5           5         5
# 16         4       4           4         4
# 17        13      13          13        13
# 18        13      13          13        13
# 19        21      21          21        21
# 20        25      25          25        25
# 21        14      14          14        14
# 22        24      24          24        24
# 23        13      13          13        13
# 24         8       8           8         8
# 25        14      14          14        14
# 26         9       9           9         9
# 27         9       9           9         9
# 28        12      12          12        12
# 29         7       7           7         7
# 30         8       8           8         8
# 31         4       4           4         4
# ...

# %%
df_users[df_users['gender'] == "M"].groupby("age").count()
# Out:
#      user_id  gender  occupation  zip_code
# age
# 7          1       1           1         1
# 10         1       1           1         1
# 11         1       1           1         1
# 13         3       3           3         3
# 15         3       3           3         3
# 16         3       3           3         3
# 17        11      11          11        11
# 18         7       7           7         7
# 19        15      15          15        15
# 20        22      22          22        22
# 21        20      20          20        20
# 22        30      30          30        30
# 23        22      22          22        22
# 24        27      27          27        27
# 25        30      30          30        30
# 26        25      25          25        25
# 27        25      25          25        25
# 28        26      26          26        26
# 29        20      20          20        20
# 30        27      27          27        27
# 31        19      19          19        19
# ...

# %%
df_users.query("occupation == 'student'").groupby(['occupation','gender']).count()
# Out:
#                    user_id  age  zip_code
# occupation gender
# student    F            60   60        60
#            M           136  136       136

# %%
df_users[df_users['occupation'] == "student"].groupby(["occupation","gender"]).count()
# Out:
#                    user_id  age  zip_code
# occupation gender
# student    F            60   60        60
#            M           136  136       136

# %%
df_users.query("occupation == 'student'").groupby(['gender']).count()
# Out:
#         user_id  age  occupation  zip_code
# gender
# F            60   60          60        60
# M           136  136         136       136

# %%
df_users[df_users['occupation'] == "student"].groupby(["gender"]).count()
# Out:
#         user_id  age  occupation  zip_code
# gender
# F            60   60          60        60
# M           136  136         136       136
