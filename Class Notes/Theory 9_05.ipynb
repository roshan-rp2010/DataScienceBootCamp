# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dates = pd.date_range(start='01-Aug-2023', end='31-Aug-2023')

# %%
dates
# Out:
# DatetimeIndex(['2023-08-01', '2023-08-02', '2023-08-03', '2023-08-04',
#                '2023-08-05', '2023-08-06', '2023-08-07', '2023-08-08',
#                '2023-08-09', '2023-08-10', '2023-08-11', '2023-08-12',
#                '2023-08-13', '2023-08-14', '2023-08-15', '2023-08-16',
#                '2023-08-17', '2023-08-18', '2023-08-19', '2023-08-20',
#                '2023-08-21', '2023-08-22', '2023-08-23', '2023-08-24',
#                '2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
M = np.random.random((7,7))
M
# Out:
# array([[0.41251801, 0.74346007, 0.98618419, 0.44352476, 0.81624066,
#         0.99281036, 0.19971567],
#        [0.25039412, 0.04600459, 0.62108108, 0.17175754, 0.65819941,
#         0.68496376, 0.52372631],
#        [0.06301845, 0.57896288, 0.50533138, 0.11453736, 0.33393121,
#         0.44213465, 0.96362875],
#        [0.0863249 , 0.04055554, 0.24491361, 0.27983934, 0.48675202,
#         0.79282033, 0.08609412],
#        [0.87757117, 0.78854774, 0.92756486, 0.10008227, 0.95456789,
#         0.67033516, 0.45669355],
#        [0.97711685, 0.96874368, 0.81872544, 0.40309495, 0.97443338,
#         0.57227297, 0.66799035],
#        [0.31002546, 0.55571468, 0.48937858, 0.74304769, 0.0768558 ,
#         0.12996821, 0.83797124]])

# %%
dates = pd.date_range(start='01-Aug-2023', end='31-Aug-2023')
dates
# Out:
# DatetimeIndex(['2023-08-01', '2023-08-02', '2023-08-03', '2023-08-04',
#                '2023-08-05', '2023-08-06', '2023-08-07', '2023-08-08',
#                '2023-08-09', '2023-08-10', '2023-08-11', '2023-08-12',
#                '2023-08-13', '2023-08-14', '2023-08-15', '2023-08-16',
#                '2023-08-17', '2023-08-18', '2023-08-19', '2023-08-20',
#                '2023-08-21', '2023-08-22', '2023-08-23', '2023-08-24',
#                '2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('today', periods=7)
dates
# Out:
# DatetimeIndex(['2023-09-06 00:30:00.154680', '2023-09-07 00:30:00.154680',
#                '2023-09-08 00:30:00.154680', '2023-09-09 00:30:00.154680',
#                '2023-09-10 00:30:00.154680', '2023-09-11 00:30:00.154680',
#                '2023-09-12 00:30:00.154680'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('2023-08-25', periods=7)
dates
# Out:
# DatetimeIndex(['2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(M, index=dates)
df
# Out:
#                    0         1         2         3         4         5  \
# 2023-08-25  0.412518  0.743460  0.986184  0.443525  0.816241  0.992810
# 2023-08-26  0.250394  0.046005  0.621081  0.171758  0.658199  0.684964
# 2023-08-27  0.063018  0.578963  0.505331  0.114537  0.333931  0.442135
# 2023-08-28  0.086325  0.040556  0.244914  0.279839  0.486752  0.792820
# 2023-08-29  0.877571  0.788548  0.927565  0.100082  0.954568  0.670335
# 2023-08-30  0.977117  0.968744  0.818725  0.403095  0.974433  0.572273
# 2023-08-31  0.310025  0.555715  0.489379  0.743048  0.076856  0.129968
#
#                    6
# 2023-08-25  0.199716
# 2023-08-26  0.523726
# 2023-08-27  0.963629
# 2023-08-28  0.086094
# 2023-08-29  0.456694
# 2023-08-30  0.667990
# 2023-08-31  0.837971

# %%
dict1 = {'A': pd.Series([1,2,3,4], index = ['a','b','c','d']),
         'B': pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
         }
df1 = pd.DataFrame(dict1)
df1
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %%
del df1['B']
df1
# Out:
#      A
# a  1.0
# b  2.0
# c  3.0
# d  4.0
# e  NaN

# %%
dict = {'A' : pd.Series([1, 2, 3,11], index=['a', 'b', 'c','d']),
'B' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}
df12 = pd.DataFrame(dict)
df12
# Out:
#     A  B
# a   1  1
# b   2  2
# c   3  3
# d  11  4

# %%
df12.drop(['A'], axis=1) # axis=0 => rows,  axis=1 => columns
df12
# Out:
#     A  B
# a   1  1
# b   2  2
# c   3  3
# d  11  4

# %%
df12.drop(['A'], axis=1, inplace=True) # axis=0 => rows,  axis=1 => columns
df12
# Out:
#    B
# a  1
# b  2
# c  3
# d  4

# %%
df12.drop(['c'], axis=0, inplace=True) # axis=0 => rows,  axis=1 => columns
df12
# Out:
#    B
# a  1
# b  2
# d  4

# %%
col1 = np.linspace(10, 100, 30)
col2 = np.random.randint(10,100,30)
df10 = pd.DataFrame({"C1" : col1 , "C2" :col2})
df10

# %%
df10 = df10.drop([17,18,19], axis=0)
df10

# %%
df10.drop([16], axis=0, inplace=True)
df10

# %%
df10.drop(df10.index[5], inplace=True)

# %%
df10.iloc[10:15]
# Out:
#            C1  C2
# 11  44.137931  60
# 12  47.241379  35
# 13  50.344828  21
# 14  53.448276  93
# 15  56.551724  56

# %%
df.loc['25-08-2023':'25-08-2023','C1':'C1']
# Out:
# <ipython-input-50-67d2a7753ad7>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['25-08-2023':'25-08-2023','C1':'C1']
# Empty DataFrame
# Columns: []
# Index: [2023-08-25 00:00:00]

# %%
df.loc['26-08-2023':'26-08-2023','C2':'C2']
# Out:
# <ipython-input-51-1fd126cf03ec>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['26-08-2023':'26-08-2023','C2':'C2']
# Empty DataFrame
# Columns: []
# Index: [2023-08-26 00:00:00]

# %%
df.loc['27-08-2023':'27-08-2023','C3':'C3']
# Out:
# <ipython-input-35-0598eea2a8b0>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['27-08-2023':'27-08-2023','C3':'C3']
# Empty DataFrame
# Columns: []
# Index: [2023-08-27 00:00:00]

# %%
df.loc['28-08-2023':'28-08-2023','C4':'C4']
# Out:
# <ipython-input-37-97a2393ef63f>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['28-08-2023':'28-08-2023','C4':'C4']
# Empty DataFrame
# Columns: []
# Index: [2023-08-28 00:00:00]

# %%
df.loc['29-08-2023':'29-08-2023','C5':'C5']
# Out:
# <ipython-input-38-d737984eb42f>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['29-08-2023':'29-08-2023','C5':'C5']
# Empty DataFrame
# Columns: []
# Index: [2023-08-29 00:00:00]

# %%
df.loc['30-08-2023':'30-08-2023','C6':'C6']
# Out:
# <ipython-input-40-999a0150c3ba>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['30-08-2023':'30-08-2023','C6':'C6']
# Empty DataFrame
# Columns: []
# Index: [2023-08-30 00:00:00]

# %%
df.loc['31-08-2023':'31-08-2023','C7':'C7']
# Out:
# <ipython-input-41-acca78fa93ce>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['31-08-2023':'31-08-2023','C7':'C7']
# Empty DataFrame
# Columns: []
# Index: [2023-08-31 00:00:00]

# %%
df.loc['31-08-2023':'31-08-2023','C1':'C1']
# Out:
# <ipython-input-42-38e3a8da8904>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['31-08-2023':'31-08-2023','C1':'C1']
# Empty DataFrame
# Columns: []
# Index: [2023-08-31 00:00:00]

# %%
df.loc['30-08-2023':'30-08-2023','C2':'C2']
# Out:
# <ipython-input-43-c519add2ac00>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['30-08-2023':'30-08-2023','C2':'C2']
# Empty DataFrame
# Columns: []
# Index: [2023-08-30 00:00:00]

# %%
df.loc['29-08-2023':'29-08-2023','C3':'C3']
# Out:
# <ipython-input-44-5dbebb6eca1f>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['29-08-2023':'29-08-2023','C3':'C3']
# Empty DataFrame
# Columns: []
# Index: [2023-08-29 00:00:00]

# %%
df.loc['28-08-2023':'28-08-2023','C4':'C4']
# Out:
# <ipython-input-45-97a2393ef63f>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['28-08-2023':'28-08-2023','C4':'C4']
# Empty DataFrame
# Columns: []
# Index: [2023-08-28 00:00:00]

# %%
df.loc['27-08-2023':'27-08-2023','C5':'C5']
# Out:
# <ipython-input-46-bca961938129>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['27-08-2023':'27-08-2023','C5':'C5']
# Empty DataFrame
# Columns: []
# Index: [2023-08-27 00:00:00]

# %%
df.loc['26-08-2023':'26-08-2023','C6':'C6']
# Out:
# <ipython-input-47-e8718737b6fc>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['26-08-2023':'26-08-2023','C6':'C6']
# Empty DataFrame
# Columns: []
# Index: [2023-08-26 00:00:00]

# %%
df.loc['25-08-2023':'25-08-2023','C7':'C7']
# Out:
# <ipython-input-48-f8296650380d>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['25-08-2023':'25-08-2023','C7':'C7']
# Empty DataFrame
# Columns: []
# Index: [2023-08-25 00:00:00]

# %%
df10.iloc[10:15]
# Out:
#            C1  C2
# 12  47.241379  35
# 13  50.344828  21
# 14  53.448276  93
# 15  56.551724  56
# 20  72.068966  56

# %%
df
# Out:
#                    0         1         2         3         4         5  \
# 2023-08-25  0.412518  0.743460  0.986184  0.443525  0.816241  0.992810
# 2023-08-26  0.250394  0.046005  0.621081  0.171758  0.658199  0.684964
# 2023-08-27  0.063018  0.578963  0.505331  0.114537  0.333931  0.442135
# 2023-08-28  0.086325  0.040556  0.244914  0.279839  0.486752  0.792820
# 2023-08-29  0.877571  0.788548  0.927565  0.100082  0.954568  0.670335
# 2023-08-30  0.977117  0.968744  0.818725  0.403095  0.974433  0.572273
# 2023-08-31  0.310025  0.555715  0.489379  0.743048  0.076856  0.129968
#
#                    6
# 2023-08-25  0.199716
# 2023-08-26  0.523726
# 2023-08-27  0.963629
# 2023-08-28  0.086094
# 2023-08-29  0.456694
# 2023-08-30  0.667990
# 2023-08-31  0.837971

# %%
df.iloc[:,:2]
# Out:
#                    0         1
# 2023-08-25  0.412518  0.743460
# 2023-08-26  0.250394  0.046005
# 2023-08-27  0.063018  0.578963
# 2023-08-28  0.086325  0.040556
# 2023-08-29  0.877571  0.788548
# 2023-08-30  0.977117  0.968744
# 2023-08-31  0.310025  0.555715

# %%
df.iloc[:,4:]
# Out:
#                    4         5         6
# 2023-08-25  0.816241  0.992810  0.199716
# 2023-08-26  0.658199  0.684964  0.523726
# 2023-08-27  0.333931  0.442135  0.963629
# 2023-08-28  0.486752  0.792820  0.086094
# 2023-08-29  0.954568  0.670335  0.456694
# 2023-08-30  0.974433  0.572273  0.667990
# 2023-08-31  0.076856  0.129968  0.837971

# %%
df.iloc[6:,:1]
# Out:
#                    0
# 2023-08-31  0.310025

# %%
df.iloc[5:6,1:2]
# Out:
#                    1
# 2023-08-30  0.968744

# %%
df.iloc[4:5,2:3]
# Out:
#                    2
# 2023-08-29  0.927565

# %%
df.iloc[3:4,3:4]
# Out:
#                    3
# 2023-08-28  0.279839

# %%
df.iloc[2:3,4:5]
# Out:
#                    4
# 2023-08-27  0.333931

# %%
df.iloc[1:2,5:6]
# Out:
#                    5
# 2023-08-26  0.684964

# %%
df.iloc[:1,6:]
# Out:
#                    6
# 2023-08-25  0.199716

# %%
path = '/content/Churn_Modelling.csv'
df_churnmodel = pd.read_csv(path)
df_churnmodel
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_churnmodel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df_churnmodel.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df_churnmodel.describe(include = "all")
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# ...

# %%
df_churnmodel.describe
# Out:
# <bound method NDFrame.describe of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
df_churnmodel.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df_churnmodel.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df_churnmodel.size
# Out:
# 140000

# %%
df_churnmodel.ndim
# Out:
# 2

# %%
df_churnmodel.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df_churnmodel.count
# Out:
# <bound method DataFrame.count of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
df_churnmodel.shape
# Out:
# (10000, 14)

# %%
df_churnmodel.isnull()
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender    Age  \
# 0         False       False    False        False      False   False  False
# 1         False       False    False        False      False   False  False
# 2         False       False    False        False      False   False  False
# 3         False       False    False        False      False   False  False
# 4         False       False    False        False      False   False  False
# ...         ...         ...      ...          ...        ...     ...    ...
# 9995      False       False    False        False      False   False  False
# 9996      False       False    False        False      False   False  False
# 9997      False       False    False        False      False   False  False
# 9998      False       False    False        False      False   False  False
# 9999      False       False    False        False      False   False  False
#
# ...

# %%
df_churnmodel.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df_churnmodel.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df_churnmodel.min()
# Out:
# RowNumber                 1
# CustomerId         15565701
# Surname               Abazu
# CreditScore             350
# Geography            France
# Gender               Female
# Age                      18
# Tenure                    0
# Balance                 0.0
# NumOfProducts             1
# HasCrCard                 0
# IsActiveMember            0
# EstimatedSalary       11.58
# Exited                    0
# dtype: object

# %%
df_churnmodel.max()
# Out:
# RowNumber              10000
# CustomerId          15815690
# Surname               Zuyeva
# CreditScore              850
# Geography              Spain
# Gender                  Male
# Age                       92
# Tenure                    10
# Balance            250898.09
# NumOfProducts              4
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    199992.48
# Exited                     1
# dtype: object

# %%
df_churnmodel.std()
# Out:
# <ipython-input-96-14cfdb04ddf1>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_churnmodel.std()
# RowNumber           2886.895680
# CustomerId         71936.186123
# CreditScore           96.653299
# Age                   10.487806
# Tenure                 2.892174
# Balance            62397.405202
# NumOfProducts          0.581654
# HasCrCard              0.455840
# IsActiveMember         0.499797
# EstimatedSalary    57510.492818
# Exited                 0.402769
# dtype: float64

# %%
df_churnmodel.sum()
# Out:
# RowNumber                                                   50005000
# CustomerId                                              156909405694
# Surname            HargraveHillOnioBoniMitchellChuBartlettObinnaH...
# CreditScore                                                  6505288
# Geography          FranceSpainFranceFranceSpainSpainFranceGermany...
# Gender             FemaleFemaleFemaleFemaleFemaleMaleMaleFemaleMa...
# Age                                                           389218
# Tenure                                                         50128
# Balance                                                 764858892.88
# NumOfProducts                                                  15302
# HasCrCard                                                       7055
# IsActiveMember                                                  5151
# EstimatedSalary                                        1000902398.81
# Exited                                                          2037
# ...

# %%
df_churnmodel.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df_churnmodel.CreditScore
# Out:
# 0       619
# 1       608
# 2       502
# 3       699
# 4       850
#        ...
# 9995    771
# 9996    516
# 9997    709
# 9998    772
# 9999    792
# Name: CreditScore, Length: 10000, dtype: int64

# %%
df_churnmodel.["CreditScore"]

# %%
df_churnmodel.CreditScore, df_churnmodel.Geography
# Out:
# (0       619
#  1       608
#  2       502
#  3       699
#  4       850
#         ...
#  9995    771
#  9996    516
#  9997    709
#  9998    772
#  9999    792
#  Name: CreditScore, Length: 10000, dtype: int64,
#  0        France
#  1         Spain
#  2        France
#  3        France
#  4         Spain
#           ...
#  9995     France
#  9996     France
#  9997     France
#  9998    Germany
#  9999     France
#  Name: Geography, Length: 10000, dtype: object)

# %%
df_churnmodel[["CreditScore","Geography"]]
# Out:
#       CreditScore Geography
# 0             619    France
# 1             608     Spain
# 2             502    France
# 3             699    France
# 4             850     Spain
# ...           ...       ...
# 9995          771    France
# 9996          516    France
# 9997          709    France
# 9998          772   Germany
# 9999          792    France
#
# [10000 rows x 2 columns]

# %%
df_churnmodel[['Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard']]
# Out:
#       Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard
# 0     Female   42       2       0.00              1          1
# 1     Female   41       1   83807.86              1          0
# 2     Female   42       8  159660.80              3          1
# 3     Female   39       1       0.00              2          0
# 4     Female   43       2  125510.82              1          1
# ...      ...  ...     ...        ...            ...        ...
# 9995    Male   39       5       0.00              2          1
# 9996    Male   35      10   57369.61              1          1
# 9997  Female   36       7       0.00              1          0
# 9998    Male   42       3   75075.31              2          1
# 9999  Female   28       4  130142.79              1          1
#
# [10000 rows x 6 columns]

# %%
df_churnmodel[df_churnmodel.Gender == "Male"]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography Gender  Age  \
# 5             6    15574012          Chu          645     Spain   Male   44
# 6             7    15592531     Bartlett          822    France   Male   50
# 8             9    15792365           He          501    France   Male   44
# 9            10    15592389           H?          684    France   Male   27
# 10           11    15767821       Bearce          528    France   Male   31
# ...         ...         ...          ...          ...       ...    ...  ...
# 9992       9993    15657105  Chukwualuka          726     Spain   Male   36
# 9993       9994    15569266       Rahman          644    France   Male   28
# 9995       9996    15606229     Obijiaku          771    France   Male   39
# 9996       9997    15569892    Johnstone          516    France   Male   35
# 9998       9999    15682355    Sabbatini          772   Germany   Male   42
#
# ...

# %%
df_churnmodel[(df_churnmodel.Gender == "Male") & (df_churnmodel.Age >= 45)]
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography Gender  Age  \
# 6             7    15592531  Bartlett          822    France   Male   50
# 15           16    15643966   Goforth          616   Germany   Male   45
# 16           17    15737452     Romeo          653   Germany   Male   58
# 18           19    15661507   Muldrow          587     Spain   Male   45
# 23           24    15725737    Mosman          669    France   Male   46
# ...         ...         ...       ...          ...       ...    ...  ...
# 9953       9954    15655952     Burke          550    France   Male   47
# 9954       9955    15739850  Trentino          645    France   Male   45
# 9967       9968    15603794  Pugliesi          623    France   Male   48
# 9975       9976    15666295     Smith          610   Germany   Male   50
# 9986       9987    15581736  Bartlett          673   Germany   Male   47
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_churnmodel[(df_churnmodel.Gender == "Male") | (df_churnmodel.Age >= 45)]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography Gender  Age  \
# 5             6    15574012          Chu          645     Spain   Male   44
# 6             7    15592531     Bartlett          822    France   Male   50
# 8             9    15792365           He          501    France   Male   44
# 9            10    15592389           H?          684    France   Male   27
# 10           11    15767821       Bearce          528    France   Male   31
# ...         ...         ...          ...          ...       ...    ...  ...
# 9992       9993    15657105  Chukwualuka          726     Spain   Male   36
# 9993       9994    15569266       Rahman          644    France   Male   28
# 9995       9996    15606229     Obijiaku          771    France   Male   39
# 9996       9997    15569892    Johnstone          516    France   Male   35
# 9998       9999    15682355    Sabbatini          772   Germany   Male   42
#
# ...

# %%
df_churnmodel[(df_churnmodel.Gender != "Male") | (df_churnmodel.Age != 45)]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_churnmodel[(df_churnmodel.Gender != "Male") & (df_churnmodel.Age != 45)]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602     Hargrave          619    France  Female   42
# 1             2    15647311         Hill          608     Spain  Female   41
# 2             3    15619304         Onio          502    France  Female   42
# 3             4    15701354         Boni          699    France  Female   39
# 4             5    15737888     Mitchell          850     Spain  Female   43
# ...         ...         ...          ...          ...       ...     ...  ...
# 9982       9983    15768163      Griffin          655   Germany  Female   46
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9994       9995    15719294         Wood          800    France  Female   29
# 9997       9998    15584532          Liu          709    France  Female   36
# 9999      10000    15628319       Walker          792    France  Female   28
#
# ...

# %%
df_churnmodel[(df_churnmodel.Gender != "Male") & ((df_churnmodel.Age <= 30) | (df_churnmodel.Age >= 50))]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 7             8    15656148       Obinna          376   Germany  Female   29
# 13           14    15691483         Chin          549    France  Female   25
# 17           18    15788218    Henderson          549     Spain  Female   24
# 19           20    15568982          Hao          726    France  Female   24
# 34           35    15732963     Clements          722     Spain  Female   29
# ...         ...         ...          ...          ...       ...     ...  ...
# 9948       9949    15735078    Onwughara          724   Germany  Female   53
# 9979       9980    15692664       Diribe          677    France  Female   58
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9994       9995    15719294         Wood          800    France  Female   29
# 9999      10000    15628319       Walker          792    France  Female   28
#
# ...

# %%
df_churnmodel[(df_churnmodel.Gender != "Male") & ((df_churnmodel.Tenure == 5) | (df_churnmodel.Tenure == 9))]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 13           14    15691483       Chin          549    France  Female   25
# 17           18    15788218  Henderson          549     Spain  Female   24
# 24           25    15625047        Yen          846    France  Female   38
# 34           35    15732963   Clements          722     Spain  Female   29
# 44           45    15684171    Bianchi          660     Spain  Female   61
# ...         ...         ...        ...          ...       ...     ...  ...
# 9942       9943    15683007     Torode          739   Germany  Female   25
# 9946       9947    15618171      James          669    France  Female   33
# 9949       9950    15798615        Wan          850    France  Female   47
# 9960       9961    15681026   Lucciano          795   Germany  Female   33
# 9977       9978    15579969    Mancini          683    France  Female   32
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...
