# %% [markdown]
# practiced some question from last day until 9:30

# %% [markdown]
# 1) Swap first and last element of the list
#
#
#
# a=[1,2,5,10,'1']

# %%
# swaps first and last elements of the list

def swap_elements(mylist1):
  felem = mylist1.pop(0)
  lelem = mylist1.pop()
  mylist1.append(felem)
  mylist1.insert(0,lelem)
  print(mylist1)


# main

mylist = input("Enter a list seperated with ',': ")
if "[" in mylist:
  mylist = mylist.replace("[","")
if "]" in mylist:
  mylist = mylist.replace("]","")
mylist = mylist.split(",")

count = 0
for i in mylist:
  if i.isdigit():
    mylist[count] = int(i)
  count += 1

print(mylist)
swap_elements(mylist)
# Out:
# Enter a list seperated with ',': [1,2,5,10,'1']
# [1, 2, 5, 10, "'1'"]
# ["'1'", 2, 5, 10, 1]

# %% [markdown]
# second method to do the same question as above:

# %%
# swaps first and last elements of the list

def swap_elements(list_temp):
  list_temp[0],list_temp[-1] = list_temp[-1],list_temp[0]
  print(list_temp)


# main

mylist = input("Enter a list seperated with ',': ")
if "[" in mylist:
  mylist = mylist.replace("[","")
if "]" in mylist:
  mylist = mylist.replace("]","")
mylist = mylist.split(",")

count = 0
for i in mylist:
  if i.isdigit():
    mylist[count] = int(i)
  count += 1

print(mylist)
swap_elements(mylist)
# Out:
# Enter a list seperated with ',': [1,2,5,10,'1']
# [1, 2, 5, 10, "'1'"]
# ["'1'", 2, 5, 10, 1]
