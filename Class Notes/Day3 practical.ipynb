# %%
print("join statement for strings, only works on strings, ")
print("takes first arg as joining string")
print()
list1 = ["Hello","world!","how","are","you?"]
print(" ".join(list1))
# Out:
# join statement for strings, only works on strings,
# takes first arg as joining string
#
# Hello world! how are you?

# %%
print("Dictionary implementations:")
print()

dict1 = {"brand":"Ford", "model":"mustand", "year": 1964, "year":2020}
print(dict1)

print()

dict2 = dict(name="John",age=52,country="US")
print(dict2)

print()

dict2.update(name="happy")
print(dict2)
# Out:
# Dictionary implementations:
#
# {'brand': 'Ford', 'model': 'mustand', 'year': 2020}
#
# {'name': 'John', 'age': 52, 'country': 'US'}
#
# {'name': 'happy', 'age': 52, 'country': 'US'}

# %%
# ascii code value for S is 83 and ascii code for P is 80
# adding 32 on ascii value of uppercase alphabets converts it to lowercase.

temp_dict = {83:80}
temp_str = "Hello Sam! Shhh"
temp_str.translate(temp_dict)
# Out:
# 'Hello Pam! Phhh'
