# %%
a = 120
b = 20

a+=b
print(a,b)
# Out:
# 140 20

# %%
a = 120
b = 20

a-=b
print(a,b)
# Out:
# 100 20

# %%
a = 120
b = 10

a *= b
print(a, b)
# Out:
# 1200 10

# %%
a = 120
b = 10

a /= b
print(a, b)
# Out:
# 12.0 10

# %%
a = 120
b = 10

a %= b
print(a, b)
# Out:
# 0 10

# %%
a = 120
b = 10

a //= b
print(a, b)
# Out:
# 12 10

# %%
a = 120
b = 2

a **= b
print(a, b)
# Out:
# 14400 2

# %%
# comparision operators

a = 120
b = 10

print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# True
# False
# True
# False

# %%
a = 150
b = [50, 100, 150, 200, 900]

print(a in b)

a = 400

print(a in b)

a = "aaa"
b = ["a","b","aa","aaa","bb"]

print(a in b)

a = "abc"

print(a in b)
# Out:
# True
# False
# True
# False

# %%
a = 2
b = 4

print(a is b)

a = 4

print(a is b)
# Out:
# False
# True
